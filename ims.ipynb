# %%
import json
    
record = {"1" : {"product name":"watch" ,"Brand_name": "Sonata" ,"Price":1150 ,"Discount Available":.5, "warranty": "1 year", "type" : "Wrist watch","Diameter":"34 mm","Color":"white","Strap Material":"metal","Water proof":"yes","Number of item available in stock":10 },
           "2": {"product name":"Western Top","Brand_name":"FAIRIANO","Price":750 ,"Discount Available":.1,"Neck":"Round","Sleeve Style":"Regular","Type":"Crop Top","Pattern":"solid","Color":"Green,white","Fabric care":"Hand wash","Number of item available in stock":5},
           "3" :{"product name":"pillo cover","Brand_name":"Durafeel","Price":250 ,"Discount Available":.1,"size":17*27,"Fill Material":"Fiber","Item Firmness Des cription":"Medium","Color":"white","shape":"Rectangular","Thread count":110,"Number of item available in stock":5},
           "4" :{"product name":"Bed sheet","Brand_name":"CHHAVI India","Price":375 ,"Discount Available":.1,"size":"Double","Material":"Microfiber","Thread count":120,"Fabric care":"Machine wash","Type":"Flat","Color":" Black,white","Number of item available in stock":6 },
           "5" :{"product name":"Fan","Brand_name":"HAVELLS ","Price":2199,"warranty": "3 year","Type":"Ceiling Fan","Motor Speed":"390 RPM","Power Consumption":'75 W',"Blade Sweep Size":'1200 mm', "Number of Speed Settings":4,"Color":" Black,white,Indigo Blue","Number of item available in stock":4,"Discount Available":.5},
           "6" :{"product name":"Laptop","Brand_name":"APPLE MacBook Pro M1","Battery Backup":"Upto 17 hours","Price":112990,"Discount Available":.1,"warranty": "1 Year Limited Warranty","Touchscreen":"NO","Water proof":"yes","Screen Size":'33.78 cm',"Color":" Black","Number of item available in stock":4},
           "7" :{"product name":"Mobile","Brand_name":"realme C21","Battery Capacity":"5000 mAh","Price":8999,"Discount Available":.1,"Domestic Warranty": "1 Year","Touchscreen Type":"Capacitive","Water proof":"no","Display Size":'16.51 cm',"Color":" Black,silver","Number of item available in stock":3},
           "8" :{"product name":"Shoes","Brand_name":"Reebok","Type":"Men,Women","Price":1899,"Discount Available":.1,"Domestic Warranty": "1 Year","Touchscreen Type":"Capacitive","Water proof":"no","Size Available":'4,5,6,7 Size- UK/India',"Color":" Black,white","Number of item available in stock":3},
           "9" :{"product name":"Iron","Brand_name":"BAJAJ","Type":"Dry","Price":699,"Discount Available":.1,"Domestic Warranty": "2 Years Bajaj India Warranty","Height":"12.2 cm","Weight":"789 g","Power Consumption":'1000 W',"Color":" white","Number of item available in stock":8},
           "10":{"product name":"Earrings","Brand_name":"JIVA","Base Material":"Sterling Silver","Color":"Silver","Ideal For":"Women, Girls","Type":"Stud Earring","Collection":"Contemporary","Price":1234,"Discount Available":.25,"Number of item available in stock":5},
           "11":{"product name":"Slippers for men","Brand_name":"MILESWALKER","Price":199,"size available":'5,6,7 Size- UK/India',"Discount Available":.1,"Color":"Grey","Strap Material":"Synthetic","Weight":"400 g","Care instructions":"Wipe with a clean dry cloth","Sole Material":"AIRMIX","Number of item available in stock":2},
           "12":{"product name":"Slippers for women","Brand_name":"Strawberry ","Price":249,"size available":'4,5,6,7 Size- UK/India',"Discount Available":.2,"Color":"Black","Strap Material":"Synthetic","Weight":"400 g","Care instructions":"Wipe with a clean dry cloth","Sole Material":"AIRMIX","Number of item available in stock":2},
           "13":{"product name":"Laptop charger","Brand_name":"HP","Price":1071,"Warranty":"1 Year HP Brand Warranty","Power Input":100-240,"Discount Available":.1,"Output Current":"19.5 A","Cable Length":"1 m","Color":"Black","Weight":"200 g","Number of item available in stock":2},
           "14":{"product name":"Mobile charger","Brand_name":"realme ","Price":449,"Discount Available":.1,"Warranty":"6 Months Warranty","Output Wattage":'10 W',"Output Current":"2 A","Cable Length":"45 cm","Color":"Black,white","Weight":"65.2 g","Number of item available in stock":3},
           "15":{"product name":"Sandle for men","Brand_name":"SPARX ","Price":669,"size available":'5,6,7 Size- UK/India',"Discount Available":.1,"Color":"Blue","Strap Material":"Synthetic","Weight":"400 g","Care instructions":"Wipe with a clean dry cloth","Sole Material":"AIRMIX","Number of item available in stock":2},
           "16":{"product name":"Slippers for women","Brand_name":"ACTION ","Price":599,"size available":'4,5,6,7 Size- UK/India',"Discount Available":.2,"Color":"Black","Strap Material":"Synthetic","Weight":"400 g","Care instructions":"Wipe with a clean dry cloth","Sole Material":"TPR","Number of item available in stock":3},
           "17":{"product name":"College bag","Brand_name":"Lunar","Price":799,"Type":"Backpack","Ideal For":"Men & Women","Trolley Support":"no","Laptop Sleeve":"No","With Rain Cover":"No","Discount Available":.1,"Color":"Black","Number of item available in stock":2},
           "18":{"product name":"Laptop bag","Brand_name":"HP","Price":664,"Laptop Sleeve":"YES","No of Compartments":4,"Material":"Nylon","Color":"Blue, Grey","Compatible Laptop Size":'15.6 inch',"Closure Type":"Zip","Width":"34 inch","Discount Available":.1,"Number of item available in stock":4},
           "19":{"product name":"Pressure Cooker","Brand_name":"Prestige","Price":1899,"Sales Package":"1 Pressure Cooker, 1 Pressure Cooker Without Lid","Capacity":'5, 3 litre',"Dishwasher Safe":'YES',"color":'silver',"Discount Available":.2,"Number of item available in stock":3},
           "20":{"product name":"Jeans for men","Brand_name":"LEVIS","Price":2199,"Suitable For":"Western Wear","Pocket Type":"Coin Pocket","Pattern":"Solid","Reversible":'No',"Closure":"Button","Fabric":"Cotton Blend","Color":"Blue","Fabric Care":'Gentle Machine Wash',"size Available": '28,30,34,40,42' ,"Discount Available":.2,"Number of item available in stock":3},  
           "21":{"product name":"Jeans for women","Brand_name":"O'Mine","Price":762,"Suitable For":"Western Wear","Pocket Type":"Diagonal Pocket","Pattern":"Solid","Reversible":'No',"Closure":"Zip With 7 Button","Fabric":"Denim","Color Available":"Blue, Black","Fabric Care":'Do Not Bleach',"size Available": '28,30,34,40,42' ,"Discount Available":.2,"Number of item available in stock":3},
           "22":{"product name":"LED Bulb","Brand_name":"Syska","Price":219,"Warranty":"1 Year Manufacturer Warranty from the Date of Invoice","Voltage":"90 - 300 V","Material":"Polycarbonate","Brand Color":"White, Cool Day Light","Energy Saving":"Yes","Discount Available":.1,"Number of item available in stock":50},
           "23":{"product name":"Eye Shadow Palette","Brand_name":"Lakmé","Price":995,"Quantity":"12 g","Color":"Multicolor","Waterproof":"yes","Finish":"Shimmer","Skin Type":"All Skin Types","Form":"Compressed Powder","Discount Available":.2,"Number of item available in stock":5},
           "24":{"product name":"Lipstick","Brand_name":"Lakmé","Price":191,"Form":"Liquid","Skin Type":"All Skin Types","Finish":"Matte","Duration":"Above 15 hrs","Color":"Red","Waterproof":"yes","Discount Available":.1,"Number of item available in stock":5},
           "25":{"product name":"Kajal","Brand_name":"Lakmé","Price":255,"Form":"Pencil","Skin Type":"All Skin Types","Finish":"Matte","Duration":"Above 15 hrs","Color":"Black","Waterproof":"yes","Discount Available":.1,"Number of item available in stock":5},
           "26":{"product name":"Window Curtain","Brand_name":"Urban Space","Price":999,"Material":"Velvet","color":"white,Red","window":"140 cm x 152 cm","Discount Available":.2,"Number of item available in stock":50},
           "27":{"product name":"Woven Kanjivaram Art Silk, Cotton Silk Saree","Brand_name":"C J Enterprise ","Price":2199,"Pattern":"Woven","Color":"Multicolor","Occasion":"Party & Festive","Decorative Material":"Zari, Resham/ Silk Thread","Discount Available":.2,"Number of item available in stock":50},
           "28":{"product name":"LED Tube Light","Brand_name":"PHILIPS  ","Price":549,"Warranty ":"1 Year","Color":"white","Material":"Aluminium","Shape":"Straight Linear","Power Consumption":"20 W","Discount Available":.1,"Number of item available in stock":100},
           "29":{"product name":"Dairy Milk Silk Bubbly Chocolate Bar ","Brand_name":"Cadbury  ","Price":215,"Maximum Shelf Life":"9 Months","Food Preference":"Vegetarian","Weight":"120 g","Discount Available":.1,"Number of item available in stock":100},
           "30":{"product name":"Table Fan","Brand_name":"BAJAJ","Price":1799,"Warranty":"1 year","Color":"white","Number of Blades": 3,"Blade Material":"Plastic, Transparent","Discount Available":.1,"Number of item available in stock":500},
           
}    
print("Are you a saler and you want to add products in your inventory ?")
ans=input("yes/no:")
if ans=='yes':
  print("Would you like to add new item in stock:yes or no-->")
  answer=input()
  if answer=='yes':
        key =input("Enter product id:")
        product_name=input("Enter product name:")
        Brand_name=input("Enter Brand name:")
        price= int(input("Enter price:"))
        Number_of_item_available_in_stock= int(input("Enter quantity:"))
        record[key]={"product name": product_name,"Brand_name":Brand_name,"Price":price,"Number of item available in stock":Number_of_item_available_in_stock}
        j=json.dumps(record)
        with open('record.json','w') as f:
            f.write(j)
            f.close()
        ans=input("Would you like to increase number of items in inventory ? yes/no -->")
        if ans=='yes':
          num=int(input("How much item you want to add ?"))
          updated_quan=Number_of_item_available_in_stock+num
          record[key]={"product name": product_name,"Brand_name":Brand_name,"Price":price,"Number of item available in stock":updated_quan}
    
  if answer=='no':
      print("OK 😀")
if ans=='no':
  print("Alright 🙂")
print("🌸Welcome to Our shop🌸")
print("press 1: To know about names of products")
print("press 2: To know about the product details")
choice=int(input("Please enter your choice:"))
if choice>2:
    print("You have entered wrong choice😑")
if choice >=1 and choice<=2:
 if choice ==1:
        print("🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻")
        for i in record:
             key=str(i)
             print(record[key]["product name"])
        print("🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻🌻")
if choice >=1 and choice<=2:
 print("Would you like to know about the product you are looking for : yes or no->")
 ans=input()
 if ans=='yes':
    choice=int(input("Please enter choice 2 to know about product:")) 
    if choice==2:
        print("********************************************************************************************************")
           
        print(record[input("Please enter the product key number to know the details about product :")])
        
        print("********************************************************************************************************")
        print("Here is your searched product 🤩 ")
        print("Do you want to buy something")
        reply=input("yes/no :")
        if(reply=='yes'):
          print("Nice 🤩")
          product_no=input("what you like to purchase please enter product number")
          print("OK ! NICE CHOICE😊")
          print("********************************************************************************")  
          print("product name :",record[product_no]["product name"])
          print("Brand name :",record[product_no]["Brand_name"])
          print("price of a product :",record[product_no]["Price"])
          print("color of product :",record[product_no]["Color"])
          print("Discount :",record[product_no]["Discount Available"])
          print("Number of item available in stock :",record[product_no]["Number of item available in stock"])
          print("********************************************************************************")  
          reply=input("Are you sure to proceed :yes/no-->")     
          if(reply=='yes'):
            print("Amazing 🤗")
            ui_prod  = str(input("Enter the product_Id: "))
            ui_quant = int(input("Enter the quantity: "))
            name=input("Enter your name :")
            address=input("Enter your address:")
            transaction_id=input("enter transaction id:")
            print("Product: ", record[ui_prod]["product name"])
            print("Price: ", record[ui_prod]["Price"])
            amount=record[ui_prod]["Price"] * ui_quant
            print("Billing Amount: ", amount)
            record[ui_prod]["Number of item available in stock"] = record[ui_prod]["Number of item available in stock"] - ui_quant     
            js = json.dumps(record)

            fd = open("record.json",'a')
            r=fd.write(js)
            fd.close()
            if(amount>1000):
                     print("CONGRATULATIONS 🎊! Discount Applied 🥳")
                     Discount_amount=amount*record[product_no]["Discount Available"]
                     Billing_amount=amount-Discount_amount
                     print("Total Billing amount after discount applied:",Billing_amount)
            import time
            purchase_time=time.ctime() 
            print("purchase_time",purchase_time)
            print("\n")
            sales_details={"transaction id":transaction_id,'prod' : ui_prod,"product name":record[ui_prod]["product name"],'qn' : ui_quant, 'amount': amount,"After Discount":Billing_amount,"Buyer name":name,"address":address,"purchase_time":purchase_time}
            k=json.dumps(sales_details)
            with open('sales_details.json','a') as f:
                f.write(k)
                f.close()
            print("-------------------")    
            print("| YOUR  INVOICE 🤗|")
            print("-------------------")
            print("\n")
            print("✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️ ")
            print("transaction id :",transaction_id)
            print("product id :",ui_prod)
            print("product name :",record[ui_prod]["product name"])
            print("Numbers of product you orderd :",ui_quant)
            print("Amount :",amount)
            if amount>1000:
                print("After Discount :",Billing_amount)
            print("Buyer name :",name)
            print("address :",address)
            print("Time of purchase :",purchase_time)
            print("✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️✂️ ")
            print("Thanks for shopping😍 Have a nice day")
            print("KEEP SHOPPING")
        if reply=='no':
          print("Thanks for visiting ! Hava a nice day 🥰 ")

 if ans=='no':
      print("Thanks for visiting ! Hava a nice day 🥰 ")
# Out:
# Are you a saler and you want to add products in your inventory ?
# yes/no:no
# Alright 🙂
# 🌸Welcome to Our shop🌸
# press 1: To know about names of products
# press 2: To know about the product details
# Please enter your choice:2
# Would you like to know about the product you are looking for : yes or no->
# yes
# Please enter choice 2 to know about product:2
# ********************************************************************************************************
# Please enter the product key number to know the details about product :5
# {'product name': 'Fan', 'Brand_name': 'HAVELLS ', 'Price': 2199, 'warranty': '3 year', 'Type': 'Ceiling Fan', 'Motor Speed': '390 RPM', 'Power Consumption': '75 W', 'Blade Sweep Size': '1200 mm', 'Number of Speed Settings': 4, 'Color': ' Black,white,Indigo Blue', 'Number of item available in stock': 4, 'Discount Available': 0.5}
# ********************************************************************************************************
# ...

# %%
# Out:
# {'transaction id': '189777',
#  'prod': '10',
#  'product name': 'Earrings',
#  'qn': 1,
#  'amount': 1234,
#  'After Discount': 925.5,
#  'Buyer name': 'Anand Kumar',
#  'address': 'Building no-543',
#  'purchase_time': 'Mon Sep  6 12:11:00 2021'}
